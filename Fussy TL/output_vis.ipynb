# %%
import output_vis as vis
import numpy as np
import matplotlib.pyplot as plt

# %%
#specify path to output .csv file
csv_path = "./evaluation/log_sum_vgg.csv"

#build dictionary from .csv file
csv_data_dict = vis.read_csv_data(csv_path)

# %% [markdown]
# # Display avaiable plots

# %%
vis.plot_pruned_model_acc(csv_data_dict)

# %%
vis.plot_pruned_size_and_time(csv_data_dict)

# %%
vis.plot_pruned_parameters_to_layers(csv_data_dict)

# %%
vis.plot_pruned_decision_f(csv_data_dict)

# %% [markdown]
# # Create custom plot

# %%
#list avaiable data
for field in csv_data_dict["models"][0]:
    print(field)
# Out:
# name
# layers left
# parameters
# parameters left
# accuracy
# Ref accuracy
# f1
# size
# time
# score

# %%
#retrive % of layers left from original model
l_left = vis.get_property_list(csv_data_dict["models"], "layers left")
l_left = list(np.float_(l_left)*100)

#retrive accuracy
acc = vis.get_property_list(csv_data_dict["models"], "accuracy")
acc = list(np.float_(acc))

#add labels
plt.ylabel("Model accuracy [%]")
plt.xlabel("Layers left in model [%]")
plt.title("Pruned model accuracy")

#plot data
plot_acc, = plt.plot(l_left, acc)
plt.show()
